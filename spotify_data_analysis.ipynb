# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('SpotifyFeatures.csv')
df.head()
# Out:
#    genre        artist_name                        track_name
# 0  Movie     Henri Salvador       C'est beau de faire un Show  \
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389  \
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232725 entries, 0 to 232724
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   genre             232725 non-null  object
#  1   artist_name       232725 non-null  object
#  2   track_name        232724 non-null  object
#  3   track_id          232725 non-null  object
#  4   popularity        232725 non-null  int64
#  5   acousticness      232725 non-null  float64
#  6   danceability      232725 non-null  float64
#  7   duration_ms       232725 non-null  int64
#  8   energy            232725 non-null  float64
#  9   instrumentalness  232725 non-null  float64
#  10  key               232725 non-null  object
#  11  liveness          232725 non-null  float64
#  12  loudness          232725 non-null  float64
#  13  mode              232725 non-null  object
#  14  speechiness       232725 non-null  float64
# ...

# %%
df.shape
# Out:
# (232725, 18)

# %%
df.isnull().sum()
# Out:
# genre               0
# artist_name         0
# track_name          1
# track_id            0
# popularity          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232725 entries, 0 to 232724
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   genre             232725 non-null  object
#  1   artist_name       232725 non-null  object
#  2   track_name        232724 non-null  object
#  3   track_id          232725 non-null  object
#  4   popularity        232725 non-null  int64
#  5   acousticness      232725 non-null  float64
#  6   danceability      232725 non-null  float64
#  7   duration_ms       232725 non-null  int64
#  8   energy            232725 non-null  float64
#  9   instrumentalness  232725 non-null  float64
#  10  key               232725 non-null  object
#  11  liveness          232725 non-null  float64
#  12  loudness          232725 non-null  float64
#  13  mode              232725 non-null  object
#  14  speechiness       232725 non-null  float64
# ...

# %%
sorted_df=df.sort_values('popularity',ascending=True)
sorted_df.head()
# Out:
#                   genre             artist_name
# 0                 Movie          Henri Salvador  \
# 74954  Children's Music             Sing n Play
# 74958  Children's Music  Children Songs Company
# 74959  Children's Music  Children Songs Company
# 74961  Children's Music  Children Songs Company
#
#                                track_name                track_id  popularity
# 0             C'est beau de faire un Show  0BRjO6ga9RKCKjfDqeFgWV           0  \
# 74954                See, See My Playmate  3WaCwwpGoxLEkFmd6cpZO5           0
# 74958           By the God - Instrumental  5yDehr9ccZo3vBO8hZXFcK           0
# 74959  Interruption Please - Instrumental  6NEULw7AmTOAYRunPWcFvn           0
# 74961                              Breeze  6v126eNn1A79yFIKGfvqLz           0
#
#        acousticness  danceability  duration_ms  energy  instrumentalness key
# 0            0.6110         0.389        99373   0.910            0.0000  C#  \
# ...

# %%
df.describe()
# Out:
#           popularity   acousticness   danceability   duration_ms
# count  232725.000000  232725.000000  232725.000000  2.327250e+05  \
# mean       41.127502       0.368560       0.554364  2.351223e+05
# std        18.189948       0.354768       0.185608  1.189359e+05
# min         0.000000       0.000000       0.056900  1.538700e+04
# 25%        29.000000       0.037600       0.435000  1.828570e+05
# 50%        43.000000       0.232000       0.571000  2.204270e+05
# 75%        55.000000       0.722000       0.692000  2.657680e+05
# max       100.000000       0.996000       0.989000  5.552917e+06
#
#               energy  instrumentalness       liveness       loudness
# count  232725.000000     232725.000000  232725.000000  232725.000000  \
# mean        0.570958          0.148301       0.215009      -9.569885
# std         0.263456          0.302768       0.198273       5.998204
# min         0.000020          0.000000       0.009670     -52.457000
# ...

# %%
popular_df=df.query('popularity>90',inplace=False).sort_values('popularity',ascending=False)
popular_df[:12]
# Out:
#             genre    artist_name
# 107804        Pop  Ariana Grande  \
# 9027        Dance  Ariana Grande
# 9026        Dance  Ariana Grande
# 86951         Rap    Post Malone
# 107803        Pop    Post Malone
# 107802        Pop  Ariana Grande
# 138918  Reggaeton   Daddy Yankee
# 66643     Hip-Hop   Daddy Yankee
# 107909        Pop   Daddy Yankee
# 86953         Rap    Post Malone
# 92824       Indie         Halsey
# 9037        Dance        Ava Max
#
#                                            track_name                track_id
# 107804                                        7 rings  14msK75pk3pA33pzPVNtBF  \
# 9027                                          7 rings  14msK75pk3pA33pzPVNtBF
# 9026         break up with your girlfriend, i'm bored  4kV4N9D1iKVxx1KLvtTpjS
# 86951                                            Wow.  6MWtB6iiXyIwun0YzU6DFP
# 107803                                           Wow.  6MWtB6iiXyIwun0YzU6DFP
# ...

# %%
df[['artist_name']].iloc[68000]
# Out:
# artist_name    $uicideBoy$
# Name: 68000, dtype: object

# %%
df['duration']=df['duration_ms'].apply(lambda x:round(x/1000))
df.drop('duration_ms',inplace=True,axis=1)

# %%
df.duration.head()
# Out:
# 0     99
# 1    137
# 2    170
# 3    152
# 4     83
# Name: duration, dtype: int64

# %%
numeric_df = df.drop(["key", "mode"], axis=1).select_dtypes(include=[float, int])
corr_df = numeric_df.corr(method="pearson")
plt.figure(figsize=(14, 6))
heatmap = sns.heatmap(corr_df, annot=True, fmt=".1g", vmin=-1, vmax=1, center=0, cmap="inferno", linewidths=1, linecolor="black")
heatmap.set_title("Correlation Heatmap between Variables")
heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation=90)
plt.show()

# %%
sample_df=df.sample(int(0.006*len(df)))

# %%
print(len(sample_df))
# Out:
# 1396

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=sample_df,y="loudness",x="energy",color="c").set(title="Loudness vs Energy Correlation")
# Out:
# [Text(0.5, 1.0, 'Loudness vs Energy Correlation')]

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=sample_df,y="danceability",x="valence",color="r").set(title="Danceability vs Valence Correlation")
# Out:
# [Text(0.5, 1.0, 'Danceability vs Valence Correlation')]

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=sample_df,y="popularity",x="loudness",color="g").set(title="Popularity vs Loudness Correlation")
# Out:
# [Text(0.5, 1.0, 'Popularity vs Loudness Correlation')]

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=sample_df,y="popularity",x="instrumentalness",color="black").set(title="Popularity vs Instrumentalness Correlation")
# Out:
# [Text(0.5, 1.0, 'Popularity vs Instrumentalness Correlation')]

# %%
# total_df = df["duration"]
# fig_dims = (18, 7)
# fig, ax = plt.subplots(figsize=fig_dims)
# sns.barplot(x="popularity", y="duration", data=df, ax=ax, ci=None).set(title="Danceability vs Duration")
# plt.xticks(rotation=90)
# plt.show()

# %%
plt.title("Duration of the Songs in Different Generes")
sns.color_palette("rocket",as_cmap=True)
sns.barplot(y='genre',x='duration',data=df)
plt.xlabel('Duration')
plt.ylabel('Geners')
# Out:
# Text(0, 0.5, 'Geners')

# %%
genre_counts = df['genre'].value_counts()
print(genre_counts)
# Out:
# genre
# Comedy              9681
# Soundtrack          9646
# Indie               9543
# Jazz                9441
# Pop                 9386
# Electronic          9377
# Children’s Music    9353
# Folk                9299
# Hip-Hop             9295
# Rock                9272
# Alternative         9263
# Classical           9256
# Rap                 9232
# World               9096
# Soul                9089
# Blues               9023
# R&B                 8992
# Anime               8936
# Reggaeton           8927
# Ska                 8874
# Reggae              8771
# Dance               8701
# Country             8664
# Opera               8280
# Movie               7806
# Children's Music    5403
# A Capella            119
# Name: count, dtype: int64

# %%
sns.set_style(style = "darkgrid")
plt.figure(figsize=(10,5))
famous = df.sort_values("popularity", ascending = False).head(10)
sns.barplot(y='genre', x='popularity', data = famous).set(title= "Top 5 Genres by Popularity")
# Out:
# [Text(0.5, 1.0, 'Top 5 Genres by Popularity')]

# %%
top_5_artist=df.groupby("artist_name").count().sort_values(by="track_name",ascending=False)["track_name"][:5]
top_5_artist
# Out:
# artist_name
# Giuseppe Verdi            1394
# Giacomo Puccini           1137
# Kimbo Children's Music     971
# Nobuo Uematsu              825
# Richard Wagner             804
# Name: track_name, dtype: int64

# %%
top_5_artist.plot.barh().set(title="Top 5 artists with most songs")
plt.show()

# %%
top_5_loudest=df[["loudness","track_name"]].sort_values(by="loudness",ascending=False)[:5]
top_5_loudest
# Out:
#        loudness                                         track_name
# 53203     3.744  Your Pretty Face Is Going to Hell - Alternate ...
# 53343     1.949                                   You Gonna Get It
# 28484     1.893                                           Daikirai
# 29314     1.610           Break the Doors - 18IF Episode 2. Ending
# 26091     1.585           We Are Your Friends - Justice Vs. Simian

# %%
plt.figure(figsize=(12,7))
sns.barplot(x="loudness",y="track_name",data=top_5_loudest).set(title="Top 5 loudest tracks")
# Out:
# [Text(0.5, 1.0, 'Top 5 loudest tracks')]

# %%
most_danceability=df[["danceability","track_name","artist_name"]].sort_values(by="danceability",ascending=False)[:5]
most_danceability
# Out:
#         danceability            track_name  artist_name
# 75396          0.989           Fuzzy Wuzzy  Juice Music
# 75762          0.987  I've Been Everywhere  Juice Music
# 26911          0.987              Sol Clap      Quantic
# 178675         0.987              Sol Clap      Quantic
# 90205          0.986               Go Girl      Pitbull

# %%
plt.figure(figsize=(12,7))
sns.barplot(x="danceability",y="artist_name",data=most_danceability).set(title="Top 5 artists with the most danceable song")
# Out:
# [Text(0.5, 1.0, 'Top 5 artists with the most danceable song')]

# %%
top_instrumental=df[["instrumentalness","track_name","artist_name"]].sort_values(by="instrumentalness",ascending=False)[:10]
top_instrumental
# Out:
#         instrumentalness                                        track_name
# 199660             0.999  Opening Titles - From "Jurassic Park" Soundtrack  \
# 203562             0.998                                 I Know What I Saw
# 31144              0.997                               Kingdom of Burmecia
# 76749              0.997      My Bonnie Lies Over the Ocean - Instrumental
# 34781              0.996                                    スリルのテーマ 〜サスペンス
# 218722             0.996                                    Walking on Air
# 205376             0.996                           It's A Real Job - Score
# 199672             0.994                            The Passing Of Théoden
# 194160             0.994                            The Orville End Titles
# 198336             0.994                                The Patronus Light
#
#                        artist_name
# 199660               John Williams
# 203562  Kyle Dixon & Michael Stein
# 31144                Nobuo Uematsu
# ...

# %%
plt.figure(figsize=(12,7))
sns.barplot(x="instrumentalness",y="track_name",data=top_instrumental).set(title="Top 10 instrumental tracks")
# Out:
# [Text(0.5, 1.0, 'Top 10 instrumental tracks')]
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 12473 (\N{KATAKANA LETTER SU}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 12522 (\N{KATAKANA LETTER RI}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 12523 (\N{KATAKANA LETTER RU}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 12398 (\N{HIRAGANA LETTER NO}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
plt.figure(figsize=(12,7))
plt.pie(x="instrumentalness",data=top_instrumental,autopct='%1.2f%%',labels=top_instrumental.track_name)
plt.title("Top 10 instrumental tracks")
plt.show()

# %%
interest_feature_cols = ["tempo", "loudness", "acousticness", "danceability", "duration_ms", "energy", "instrumentalness", "liveness", "speechiness", "valence"]

# %%
df1=pd.read_csv('dataset.csv')
print(df1[interest_feature_cols])
# Out:
#           tempo  loudness  acousticness  danceability  duration_ms  energy
# 0        87.917    -6.746        0.0322         0.676       230666  0.4610  \
# 1        77.489   -17.235        0.9240         0.420       149610  0.1660
# 2        76.332    -9.734        0.2100         0.438       210826  0.3590
# 3       181.740   -18.515        0.9050         0.266       201933  0.0596
# 4       119.949    -9.681        0.4690         0.618       198853  0.4430
# ...         ...       ...           ...           ...          ...     ...
# 113995  125.995   -16.393        0.6400         0.172       384999  0.2350
# 113996   85.239   -18.318        0.9940         0.174       385000  0.1170
# 113997  132.378   -10.895        0.8670         0.629       271466  0.3290
# 113998  135.960   -10.889        0.3810         0.587       283893  0.5060
# 113999   79.198   -10.204        0.6810         0.526       241826  0.4870
#
#         instrumentalness  liveness  speechiness  valence
# ...

# %%
for feature_col in interest_feature_cols:
    pos_data=df1[df1["explicit"] == "True"] [feature_col]
    neg_data=df1[df1 ["explicit"] == "False"][feature_col]
plt.figure(figsize=(12, 7))
sns.histplot(pos_data, bins=30, label="Positive",color="green")
sns.histplot (neg_data, bins=30, label="Negative", color="red")
plt.legend (loc= "upper right")
plt.title(f"Positive And Negative Histogram Plot For {feature_col}")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 1.0, 'Positive And Negative Histogram Plot For valence')

# %%
import seaborn as sns
print(sns.__version__)
# Out:
# 0.13.2

# %%
duration_counts = df['duration'].value_counts()
print(duration_counts.head())
# Out:
# duration
# 206    1763
# 215    1758
# 212    1743
# 219    1733
# 200    1723
# Name: count, dtype: int64

# %%
genre_counts = df['genre'].value_counts()
print(genre_counts.head())
# Out:
# genre
# Comedy        9681
# Soundtrack    9646
# Indie         9543
# Jazz          9441
# Pop           9386
# Name: count, dtype: int64
